# %%
from sentinel_tiles import sentinel_tiles
from VNP09GA_002 import VNP09GA

# %%
tile = "11SPS"
date_UTC = "2025-05-27"

# %%
geometry = sentinel_tiles.grid(tile)
geometry
# Out:
# {
#   "dimensions": {
#     "rows": 3660,
#     "cols": 3660
#   },
#   "bbox": {
#     "xmin": 600000.0,
#     "ymin": 3590220.0,
#     "xmax": 709800.0,
#     "ymax": 3700020.0
#   },
#   "crs": "EPSG:32611",
#   "resolution": {
#     "cell_width": 30.0,
#     "cell_height": -30.0
#   }
# }

# %%
VNP09GA_connection = VNP09GA()
VNP09GA_connection

# %%
VNP09GA_connection.variable(variable="NDVI", date_UTC=date_UTC, geometry=geometry)
# Out:
# searching for granules
# [2025-05-29 13:30:58 INFO] You're now authenticated with NASA Earthdata Login
# [2025-05-29 13:30:59 INFO] Found the following granules for VIIRS 2 using the CMR search:
# [2025-05-29 13:30:59 INFO]   VNP09GA.A2025147.h08v05.002.2025148125140
# [2025-05-29 13:30:59 INFO] Number of VIIRS 2 granules found using CMR search: 1
# retrieving granules
# [2025-05-29 13:30:59 INFO]  Getting 1 granules, approx download size: 0.06 GB
# QUEUEING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# [2025-05-29 13:30:59 INFO] File VNP09GA.A2025147.h08v05.002.2025148125140.h5 already downloaded
# PROCESSING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/1 [00:00<?, ?it/s]
# extracting images
# [2025-05-29 13:30:59 INFO] opening VIIRS file: ~/data/VNP21A1D_002/VNP09GA.002/2025-05-27/VNP09GA.A2025147.h08v05.002.2025148125140.h5
# ...

# %%
VNP09GA_connection.variable(variable="albedo", date_UTC=date_UTC, geometry=geometry)
# Out:
# searching for granules
# [2025-05-29 13:31:03 INFO] Found the following granules for VIIRS 2 using the CMR search:
# [2025-05-29 13:31:03 INFO]   VNP09GA.A2025147.h08v05.002.2025148125140
# [2025-05-29 13:31:03 INFO] Number of VIIRS 2 granules found using CMR search: 1
# retrieving granules
# [2025-05-29 13:31:03 INFO]  Getting 1 granules, approx download size: 0.06 GB
# QUEUEING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# [2025-05-29 13:31:03 INFO] File VNP09GA.A2025147.h08v05.002.2025148125140.h5 already downloaded
# PROCESSING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/1 [00:00<?, ?it/s]
# extracting images
# [2025-05-29 13:31:03 INFO] opening VIIRS file: ~/data/VNP21A1D_002/VNP09GA.002/2025-05-27/VNP09GA.A2025147.h08v05.002.2025148125140.h5
# [2025-05-29 13:31:03 INFO] loading HDFEOS/GRIDS/VIIRS_Grid_1km_2D/Data Fields/SurfReflect_M1_1 at 926.63 m resolution
# ...
