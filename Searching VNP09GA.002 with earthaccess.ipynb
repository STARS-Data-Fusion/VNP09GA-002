# %%
import VNP09GA_002

# %%
import logging

logger = logging.getLogger(__name__)

# %%
tile = "h08v05"
date_UTC = "2025-05-27"

# %%
granule = VNP09GA_002.retrieve_granule(
    date_UTC=date_UTC,
    tile=tile
)

granule
# Out:
# [2025-05-29 13:03:39 INFO] You're now authenticated with NASA Earthdata Login
# [2025-05-29 13:03:41 INFO] Found the following granules for VIIRS 2 using the CMR search:
# [2025-05-29 13:03:41 INFO]   VNP09GA.A2025147.h08v05.002.2025148125140
# [2025-05-29 13:03:41 INFO] Number of VIIRS 2 granules found using CMR search: 1
# [2025-05-29 13:03:41 INFO]  Getting 1 granules, approx download size: 0.06 GB
# QUEUEING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# PROCESSING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/1 [00:00<?, ?it/s]
# {
#   "filename": "~/data/VNP21A1D_002/VNP09GA.002/2025-05-27/VNP09GA.A2025147.h08v05.002.2025148125140.h5"
# }

# %%
granule.NDVI
# Out:
# [2025-05-29 13:03:46 INFO] opening VIIRS file: ~/data/VNP21A1D_002/VNP09GA.002/2025-05-27/VNP09GA.A2025147.h08v05.002.2025148125140.h5
# [2025-05-29 13:03:46 INFO] loading HDFEOS/GRIDS/VIIRS_Grid_500m_2D/Data Fields/SurfReflect_I1_1 at 463.31 m resolution
# [2025-05-29 13:03:46 INFO] opening VIIRS file: ~/data/VNP21A1D_002/VNP09GA.002/2025-05-27/VNP09GA.A2025147.h08v05.002.2025148125140.h5
# [2025-05-29 13:03:46 INFO] loading HDFEOS/GRIDS/VIIRS_Grid_500m_2D/Data Fields/SurfReflect_I2_1 at 463.31 m resolution

# %%
granule.albedo
# Out:
# [2025-05-29 13:03:47 INFO] opening VIIRS file: ~/data/VNP21A1D_002/VNP09GA.002/2025-05-27/VNP09GA.A2025147.h08v05.002.2025148125140.h5
# [2025-05-29 13:03:47 INFO] loading HDFEOS/GRIDS/VIIRS_Grid_1km_2D/Data Fields/SurfReflect_M1_1 at 926.63 m resolution
# [2025-05-29 13:03:47 INFO] opening VIIRS file: ~/data/VNP21A1D_002/VNP09GA.002/2025-05-27/VNP09GA.A2025147.h08v05.002.2025148125140.h5
# [2025-05-29 13:03:47 INFO] loading HDFEOS/GRIDS/VIIRS_Grid_1km_2D/Data Fields/SurfReflect_M2_1 at 926.63 m resolution
# [2025-05-29 13:03:47 INFO] opening VIIRS file: ~/data/VNP21A1D_002/VNP09GA.002/2025-05-27/VNP09GA.A2025147.h08v05.002.2025148125140.h5
# [2025-05-29 13:03:47 INFO] loading HDFEOS/GRIDS/VIIRS_Grid_1km_2D/Data Fields/SurfReflect_M3_1 at 926.63 m resolution
# [2025-05-29 13:03:47 INFO] opening VIIRS file: ~/data/VNP21A1D_002/VNP09GA.002/2025-05-27/VNP09GA.A2025147.h08v05.002.2025148125140.h5
# ...
