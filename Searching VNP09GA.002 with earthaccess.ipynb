# %%
import VNP09GA_002

# %%
import logging

logger = logging.getLogger(__name__)

# %%
tile = "h08v05"
date_UTC = "2024-11-11"
download_directory = "~/data/VIIRS_download"

# %%
granule = VNP09GA_002.retrieve_granule(
    date_UTC=date_UTC,
    tile=tile,
    download_directory=download_directory
)

granule
# Out:
# [2024-12-04 21:02:01 INFO] Found the following granules for VIIRS 2 using the CMR search:
# [2024-12-04 21:02:01 INFO]   VNP09GA.A2024316.h08v05.002.2024320161933
# [2024-12-04 21:02:01 INFO] Number of VIIRS 2 granules found using CMR search: 1
# [2024-12-04 21:02:01 INFO]  Getting 1 granules, approx download size: 0.07 GB
# QUEUEING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# [2024-12-04 21:02:01 INFO] File VNP09GA.A2024316.h08v05.002.2024320161933.h5 already downloaded
# PROCESSING TASKS | :   0%|          | 0/1 [00:00<?, ?it/s]
# COLLECTING RESULTS | :   0%|          | 0/1 [00:00<?, ?it/s]
# {
#   "filename": "~/data/VIIRS_download/VNP09GA.002/2024-11-11/VNP09GA.A2024316.h08v05.002.2024320161933.h5"
# }

# %%
granule.NDVI
# Out:
# [2024-12-04 21:02:08 INFO] opening VIIRS file: ~/data/VIIRS_download/VNP09GA.002/2024-11-11/VNP09GA.A2024316.h08v05.002.2024320161933.h5
# [2024-12-04 21:02:08 INFO] loading HDFEOS/GRIDS/VIIRS_Grid_500m_2D/Data Fields/SurfReflect_I1_1 at 463.31 m resolution
# [2024-12-04 21:02:08 INFO] opening VIIRS file: ~/data/VIIRS_download/VNP09GA.002/2024-11-11/VNP09GA.A2024316.h08v05.002.2024320161933.h5
# [2024-12-04 21:02:08 INFO] loading HDFEOS/GRIDS/VIIRS_Grid_500m_2D/Data Fields/SurfReflect_I2_1 at 463.31 m resolution
# /opt/homebrew/Caskroom/mambaforge/base/envs/VNP09GA-002/lib/python3.11/site-packages/rasters/raster.py:248: RuntimeWarning: divide by zero encountered in divide
#   result = self.contain(self.array.__truediv__(data, *args, **kwargs))
